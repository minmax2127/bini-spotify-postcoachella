# %%
#!pip install pandas
#!pip install matplotlib numpy seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Scrape Spotify Charts for the dataset
